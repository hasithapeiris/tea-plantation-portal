# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
import statsmodels.api as sm
from scipy.stats import skew
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
# Load dataset
df = pd.read_csv("tea_forex.csv", parse_dates=["Year-Month"], index_col="Year-Month")

# %%
df.head()
# Out:
#             High_Grown_Production_(Kg)  Mid_Grown_Production_(Kg)  \
# Year-Month
# 2012-01-01                  5361185.05                 3652353.15
# 2012-02-01                  5538399.31                 3955745.75
# 2012-03-01                  6385525.09                 4625138.90
# 2012-04-01                  7323011.00                 5748401.20
# 2012-05-01                  8726319.70                 5898297.10
#
#             Low_Grown_Production_(Kg)  National_Production_(Kg)  \
# Year-Month
# 2012-01-01                14348315.90               23361854.10
# 2012-02-01                13133213.00               22627358.06
# 2012-03-01                17929328.00               28939991.99
# 2012-04-01                16982493.50               30053905.70
# 2012-05-01                18086627.25               32711244.05
#
#             FEE_(Million_USD)
# Year-Month
# 2012-01-01              95.32
# 2012-02-01             100.17
# 2012-03-01             130.31
# 2012-04-01             110.41
# 2012-05-01             149.19

# %%
# Plot the time series
plt.figure(figsize=(12, 5))
plt.plot(df['National_Production_(Kg)'], marker='o', linestyle='-')
plt.title("Monthly National Tea Production")
plt.xlabel("Year-Month")
plt.ylabel("Production (Kg)")
plt.grid()
plt.show()

# %%
# Augmented Dickey-Fuller (ADF) Test for stationarity
def adf_test(series):
    result = adfuller(series)
    print("ADF Statistic:", result[0])
    print("p-value:", result[1])
    print("Critical Values:", result[4])
    if result[1] <= 0.05:
        print("Series is stationary.")
    else:
        print("Series is NOT stationary.")

# %%
print("ADF Test Before Differencing:")
adf_test(df["National_Production_(Kg)"])
# Out:
# ADF Test Before Differencing:
# ADF Statistic: -0.894501201586031
# p-value: 0.7897778567663785
# Critical Values: {'1%': -3.4808880719210005, '5%': -2.8836966192225284, '10%': -2.5785857598714417}
# Series is NOT stationary.

# %%
print("Skewness before Box-Cox:", skew(df["National_Production_(Kg)"]))
# If skewness is between -1 and 1, transformation isn’t needed.
# Out:
# Skewness before Box-Cox: 0.29146981921421766

# %%
# First Differencing
df["NTP_Diff"] = df["National_Production_(Kg)"].diff().dropna()

# %%
print("ADF Test After First Differencing:")
adf_test(df["NTP_Diff"].dropna())
# Out:
# ADF Test After First Differencing:
# ADF Statistic: -6.966933408278948
# p-value: 8.86545571015707e-10
# Critical Values: {'1%': -3.4808880719210005, '5%': -2.8836966192225284, '10%': -2.5785857598714417}
# Series is stationary.

# %%
# ACF & PACF Plots to determine ARIMA parameters
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
plot_acf(df["NTP_Diff"].dropna(), ax=axes[0])
plot_pacf(df["NTP_Diff"].dropna(), ax=axes[1])
plt.show()

# %%
# Split data into train and test sets
train_size = int(len(df) * 0.8)
train, test = df["National_Production_(Kg)"][:train_size], df["National_Production_(Kg)"][train_size:]

# %%
# Train ARIMA Model
p, d, q = 9, 1, 12
model = ARIMA(train, order=(p, d, q)).fit()

# %%
# Print Model Summary
print(model.summary())
# Out:
#                                   SARIMAX Results
# ====================================================================================
# Dep. Variable:     National_Production_(Kg)   No. Observations:                  115
# Model:                      ARIMA(9, 1, 12)   Log Likelihood               -1873.011
# Date:                      Tue, 18 Mar 2025   AIC                           3790.023
# Time:                              15:54:35   BIC                           3850.219
# Sample:                          01-01-2012   HQIC                          3814.453
#                                - 07-01-2021
# Covariance Type:                        opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1347      0.231      0.583      0.560      -0.318       0.587
# ar.L2          0.4379      0.178      2.454      0.014       0.088       0.788
# ar.L3         -1.2743      0.269     -4.733      0.000      -1.802      -0.747
# ar.L4          0.0139      0.397      0.035      0.972      -0.763       0.791
# ar.L5          0.3523      0.250      1.409      0.159      -0.138       0.843
# ar.L6         -1.0871      0.377     -2.883      0.004      -1.826      -0.348
# ar.L7          0.0698      0.226      0.308      0.758      -0.374       0.514
# ar.L8          0.1179      0.205      0.574      0.566      -0.285       0.520
# ar.L9         -0.7788      0.169     -4.621      0.000      -1.109      -0.448
# ma.L1         -0.5877      0.347     -1.695      0.090      -1.267       0.092
# ma.L2         -0.6589      0.268     -2.459      0.014      -1.184      -0.134
# ma.L3          1.3095      0.354      3.695      0.000       0.615       2.004
# ma.L4         -0.5028      0.587     -0.857      0.392      -1.653       0.648
# ma.L5         -0.5230      0.331     -1.580      0.114      -1.172       0.126
# ma.L6          1.0822      0.512      2.112      0.035       0.078       2.087
# ma.L7         -0.6009      0.412     -1.458      0.145      -1.409       0.207
# ma.L8         -0.4312      0.225     -1.917      0.055      -0.872       0.010
# ma.L9          0.6309      0.298      2.119      0.034       0.047       1.214
# ma.L10        -0.1524      0.201     -0.760      0.447      -0.546       0.241
# ma.L11        -0.2145      0.114     -1.879      0.060      -0.438       0.009
# ma.L12        -0.2447      0.129     -1.902      0.057      -0.497       0.007
# sigma2      9.053e+12    1.4e-13   6.48e+25      0.000    9.05e+12    9.05e+12
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.59   Jarque-Bera (JB):                 0.83
# Prob(Q):                              0.21   Prob(JB):                         0.66
# Heteroskedasticity (H):               0.80   Skew:                             0.07
# Prob(H) (two-sided):                  0.50   Kurtosis:                         3.39
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.75e+42. Standard errors may be unstable.

# %%
# Forecast future values
forecast = model.forecast(steps=len(test))

# %%
# Plot Actual vs. Forecast
plt.figure(figsize=(12, 5))
plt.plot(df.index[train_size:], test, label="Actual", marker="o")
plt.plot(df.index[train_size:], forecast, label="Forecast", marker="o", color='#00A36C', linestyle="dashed")
plt.title("ARIMA Model Forecast")
plt.xlabel("Year-Month")
plt.ylabel("NTP (Billion Kg)")
plt.legend()
plt.grid()
plt.show()

# %%
# Plot Actual vs. Forecast, including train and test data
plt.figure(figsize=(12, 5))
plt.plot(df.index[:train_size], train, label="Train Data")
plt.plot(df.index[train_size:], test, label="Test Data", color="#F4BB44")
plt.plot(df.index[train_size:], forecast, label="Forecast", color="#00A36C", linestyle="dashed")
plt.title("ARIMA Model Forecast with Train, Test, and Predictions")
plt.xlabel("Year-Month")
plt.ylabel("NTP (Billion Kg)")
plt.legend()
plt.grid()
plt.show()

# %%
# Model Evaluation
mse = mean_squared_error(test, forecast)
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(test, forecast)

print(f"\nModel Evaluation Metrics:")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape * 100:.4f}")
print(f"Akaike Information Criterion (AIC): {model.aic:.4f}")
# Out:
# Model Evaluation Metrics:
# Mean Squared Error (MSE): 21125892289089.2266
# Root Mean Squared Error (RMSE): 4596291.1449
# Mean Absolute Percentage Error (MAPE): 19.7974
# Akaike Information Criterion (AIC): 3790.0225

# %%
residuals = model.resid
sm.qqplot(residuals, line='s')
plt.show()
# If residuals deviate significantly from normality, more tuning is needed.

# %%
# Forecast for the next 60 months
forecast_steps = 36
future_index = pd.date_range(start=df.index[-1], periods=forecast_steps+1, freq='M')[1:]  # Generate future months
future_forecast = model.forecast(steps=forecast_steps)

# Plot Results
plt.figure(figsize=(12,6))
plt.plot(df.index, df['National_Production_(Kg)'], label='Actual Production')
plt.plot(future_index, future_forecast, label='Forecasted Production', linestyle='dashed')
plt.legend()
plt.show()

# %%
# Create a new data frame
forecast_df = pd.DataFrame({
    'month': future_index.strftime('%Y-%m'),
    'nationalProduction': (future_forecast / 1e6).round(2),
})

# Save forecast to CSV
forecast_df.to_csv('ntp_forecast_3_years.csv', index=False)

print("Forecast saved as 'ntp_forecast.csv'")
# Out:
# Forecast saved as 'ntp_forecast.csv'

# %%
forecast_df.head(15)
# Out:
#               month  nationalProduction
# 2021-08-01  2024-01               24.03
# 2021-09-01  2024-02               24.39
# 2021-10-01  2024-03               22.16
# 2021-11-01  2024-04               23.83
# 2021-12-01  2024-05               23.43
# 2022-01-01  2024-06               25.20
# 2022-02-01  2024-07               25.20
# 2022-03-01  2024-08               25.65
# 2022-04-01  2024-09               25.99
# 2022-05-01  2024-10               26.35
# 2022-06-01  2024-11               27.38
# 2022-07-01  2024-12               27.40
# 2022-08-01  2025-01               26.33
# 2022-09-01  2025-02               25.02
# 2022-10-01  2025-03               22.79
