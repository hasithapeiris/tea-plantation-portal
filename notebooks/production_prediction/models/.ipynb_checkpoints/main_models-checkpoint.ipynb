# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from scipy.stats import boxcox
from scipy.special import inv_boxcox
from sklearn.metrics import mean_absolute_percentage_error

# %%
# Load the dataset
data = pd.read_csv('tea_forex.csv')
data['Year-Month'] = pd.to_datetime(data['Year-Month'])
data.set_index('Year-Month', inplace=True)

# %%
data.head()
# Out:
#             High_Grown_Production_(Kg)  Mid_Grown_Production_(Kg)  \
# Year-Month
# 2012-01-01                  5361185.05                 3652353.15
# 2012-02-01                  5538399.31                 3955745.75
# 2012-03-01                  6385525.09                 4625138.90
# 2012-04-01                  7323011.00                 5748401.20
# 2012-05-01                  8726319.70                 5898297.10
#
#             Low_Grown_Production_(Kg)  National_Production_(Kg)  \
# Year-Month
# 2012-01-01                14348315.90               23361854.10
# 2012-02-01                13133213.00               22627358.06
# 2012-03-01                17929328.00               28939991.99
# 2012-04-01                16982493.50               30053905.70
# 2012-05-01                18086627.25               32711244.05
#
#             FEE_(Million_USD)
# Year-Month
# 2012-01-01              95.32
# 2012-02-01             100.17
# 2012-03-01             130.31
# 2012-04-01             110.41
# 2012-05-01             149.19

# %%
# 1. Augmented Dickey-Fuller (ADF) Test for stationarity
def adf_test(series):
    result = adfuller(series)
    print("ADF Statistic:", result[0])
    print("p-value:", result[1])
    print("Critical Values:", result[4])
    if result[1] <= 0.05:
        print("Series is stationary.")
    else:
        print("Series is NOT stationary.")

# %%
adf_test(data["FEE_(Million_USD)"][12:])
# Out:
# ADF Statistic: -2.3672067529860374
# p-value: 0.15120673412306912
# Critical Values: {'1%': -3.4870216863700767, '5%': -2.8863625166643136, '10%': -2.580009026141913}
# Series is NOT stationary.

# %%
adf_test(data["National_Production_(Kg)"][12:])
# Out:
# ADF Statistic: -1.2533763278787415
# p-value: 0.6502238435542471
# Critical Values: {'1%': -3.486055829282407, '5%': -2.8859430324074076, '10%': -2.5797850694444446}
# Series is NOT stationary.

# %%
from scipy.stats import skew

print("Skewness FEE:", skew(data["FEE_(Million_USD)"]))
print("Skewness NTP:", skew(data["National_Production_(Kg)"]))
# If skewness is between -1 and 1, transformation isn’t needed.
# Out:
# Skewness FEE: 0.14176181466959217
# Skewness NTP: 0.29146981921421766

# %%
# Apply Box-Cox Transformation
# data['Production_Boxcox'], prod_lambda = boxcox(data['National_Production_(Kg)'])
# data['Forex_Boxcox'], forex_lambda = boxcox(data['FEE_(Million_USD)'])

# %%
# Differencing 1
data['Production_diff'] = data['National_Production_(Kg)'].diff().dropna()
data['Forex_diff'] = data['FEE_(Million_USD)'].diff().dropna()
data.dropna(inplace=True)

# %%
adf_test(data["Forex_diff"][12:])
# Out:
# ADF Statistic: -3.1635495507011684
# p-value: 0.022193921855847027
# Critical Values: {'1%': -3.4870216863700767, '5%': -2.8863625166643136, '10%': -2.580009026141913}
# Series is stationary.

# %%
adf_test(data["Production_diff"][12:])
# Out:
# ADF Statistic: -6.466418929100228
# p-value: 1.4016234902528989e-08
# Critical Values: {'1%': -3.486055829282407, '5%': -2.8859430324074076, '10%': -2.5797850694444446}
# Series is stationary.

# %%
# Train-test split
train_size = int(len(data) * 0.8)
train, test = data.iloc[:train_size], data.iloc[train_size:]

# %%
# ARIMA Model for Production
prod_model = ARIMA(train['National_Production_(Kg)'], order=(9,1,12)).fit()
prod_forecast = prod_model.forecast(steps=len(test))
# prod_forecast = inv_boxcox(prod_forecast, prod_lambda)
# Out:
# C:\Users\hasit\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\hasit\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\hasit\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\hasit\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# ARIMAX Model for Forex (Using Production as Exogenous Variable)
forex_model = ARIMA(train['FEE_(Million_USD)'], order=(11,1,12), exog=train['National_Production_(Kg)']).fit()
forex_forecast = forex_model.forecast(steps=len(test), exog=test['National_Production_(Kg)'])
# forex_forecast = inv_boxcox(forex_forecast, forex_lambda)
# Out:
# C:\Users\hasit\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\hasit\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\hasit\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\hasit\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# MAPE Calculation
prod_mape = mean_absolute_percentage_error(test['National_Production_(Kg)'], prod_forecast)
forex_mape = mean_absolute_percentage_error(test['FEE_(Million_USD)'], forex_forecast)
print(f'Production Forecast MAPE: {prod_mape:.2%}')
print(f'Forex Forecast MAPE: {forex_mape:.2%}')
# Out:
# Production Forecast MAPE: 21.07%
# Forex Forecast MAPE: 9.52%

# %%
# Residual Analysis
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.hist(prod_model.resid, bins=20)
plt.title("Production Model Residuals")
plt.subplot(1,2,2)
plt.hist(forex_model.resid, bins=20)
plt.title("Forex Model Residuals")
plt.show()

# %%
# Forecasting for Next 60 Months
future_index = pd.date_range(start=data.index[-1], periods=61, freq='M')[1:]
future_prod_forecast = prod_model.forecast(steps=60)
# future_prod_forecast = inv_boxcox(future_prod_forecast, prod_lambda)
future_forex_forecast = forex_model.forecast(steps=60, exog=future_prod_forecast)
# future_forex_forecast = inv_boxcox(future_forex_forecast, forex_lambda)
# Out:
# C:\Users\hasit\AppData\Local\Temp\ipykernel_3804\790434405.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_index = pd.date_range(start=data.index[-1], periods=61, freq='M')[1:]

# %%
# Plot Results
plt.figure(figsize=(12,6))
plt.plot(data.index, data['National_Production_(Kg)'], label='Actual Production')
plt.plot(future_index, future_prod_forecast, label='Forecasted Production', linestyle='dashed')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(data.index, data['FEE_(Million_USD)'], label='Actual Forex Earnings')
plt.plot(future_index, future_forex_forecast, label='Forecasted Forex Earnings', linestyle='dashed')
plt.legend()
plt.show()

# %%
# Create a DataFrame for Monthly Forecast Analysis
forecast_table = pd.DataFrame({
    'Date': future_index,
    'Forecasted_Production': future_prod_forecast,
    'Forecasted_Forex_Earnings': future_forex_forecast
})

# %%
# Save the table to CSV
forecast_table.to_csv('forecasted_values.csv', index=False)

# %%
# Print the first few rows of the forecast table
forecast_table.head()
# Out:
#                  Date  Forecasted_Production  Forecasted_Forex_Earnings
# 2021-08-01 2024-01-31           2.371386e+07                 108.227125
# 2021-09-01 2024-02-29           2.213925e+07                  97.835374
# 2021-10-01 2024-03-31           2.216141e+07                  97.240652
# 2021-11-01 2024-04-30           2.351971e+07                 106.523057
# 2021-12-01 2024-05-31           2.545916e+07                 103.417412
